# %% [markdown]
# ![Vidi_Waterflux_Banner](https://raw.githubusercontent.com/ITC-Water-Resources/Vidi-waterflux-merch/refs/heads/main/jupyter/Vidi_Waterflux_Banner.png)
# *Roelof Rietbroek, Sedigheh Karimi, Amin Shakya EGU 2025*
#
# # Compute total monthly precipitation and evapotranspiration for the relevant basins

# %%
import os
import geopandas as gpd
import shxarray
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

from common.config import read_config

# %%
conf=read_config()
datadir=conf["dataroot"]

# %%
basinsgpkg=os.path.join(datadir,'hydroshed_csl03_gl_l02.gpkg')
gdfbasins=gpd.read_file(basinsgpkg)
gdfbasins.head()
# Out:
#    PFAF_ID    HYBAS_ID  NEXT_DOWN   NEXT_SINK    MAIN_BAS  DIST_SINK  \
# 0      111  1030000010          0  1030000010  1030000010        0.0
# 1      112  1030003990          0  1030003990  1030003990        0.0
# 2      114  1030008100          0  1030008100  1030008100        0.0
# 3      117  1030008110          0  1030008110  1030008110        0.0
# 4      122  1030011660          0  1030011660  1030011660        0.0
#
#    DIST_MAIN   SUB_AREA    UP_AREA  ENDO  COAST  ORDER  SORT  \
# 0        0.0   236343.2   236343.2     0      1      0     1
# 1        0.0   519027.5   519027.5     0      1      0     2
# 2        0.0   797881.4   797881.4     0      0      1     3
# 3        0.0  1040194.7  1040194.7     0      1      0     4
# 4        0.0  1378103.3  1378121.1     0      0      1     6
#
#                    name                                           geometry
# 0                 SETIT  MULTIPOLYGON (((39.76528 15.42917, 39.75492 15...
# 1  GULF OF ADEN/SOMALIA  MULTIPOLYGON (((40.81528 14.75417, 40.79561 14...
# 2              SHEBELLE  MULTIPOLYGON (((36.74167 4.06667, 36.74131 4.0...
# 3                RUFIJI  MULTIPOLYGON (((40.84444 -2.43333, 40.83833 -2...
# 4               ZAMBEZI  MULTIPOLYGON (((35.2625 -18.23333, 35.26215 -1...

# %%
p_et=os.path.join(datadir,'precip_evap_flux_monthly.nc')
ds=xr.open_dataset(p_et)
#chunks=dict()
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:     (valid_time: 279, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-01-01T06:00:00 ... 2025-...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      (valid_time) <U4 4kB ...
# Data variables:
#     avg_ie      (valid_time, latitude, longitude) float32 1GB ...
#     avg_tprate  (valid_time, latitude, longitude) float32 1GB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts

# %%
ds_flux=ds.where(ds.valid_time>np.datetime64("2002-03-01T06:00:00.000000000"),drop=True)
display(ds_flux) ## Select time period overlapping with GRACE/GRACE-(FO)
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:     (valid_time: 276, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      (valid_time) <U4 4kB '0001' '0001' '0001' ... '0005' '0005'
# Data variables:
#     avg_ie      (valid_time, latitude, longitude) float32 1GB -4.279e-07 ... ...
#     avg_tprate  (valid_time, latitude, longitude) float32 1GB 4.59e-06 ... 3....
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts

# %%
## Visualize precipitation and evapotranspiration in mm per day unit

fig,axs=plt.subplots(ncols=2,nrows=1,figsize=(15,8),subplot_kw=dict(projection=ccrs.PlateCarree()))

ds_scld=ds_flux*(24*3600) # Convert kg m**-2 s**-1 to mm per day

im1=ds_scld.avg_tprate[20].plot(ax=axs[0],add_colorbar=False)
plt.colorbar(im1,fraction=0.03).set_label("Precipitation")
axs[0].coastlines()

im2=ds_scld.avg_ie[20].plot(ax=axs[1],add_colorbar=False)
plt.colorbar(im2,fraction=0.03).set_label("Evapotranspiration")
axs[1].coastlines()
plt.tight_layout()

# %%
import geopandas as gpd
import xarray as xr
import numpy as np
import pandas as pd
from shapely.geometry import Point

def era5_polygonmask(basinpolys,dsera5) ->xr.DataArray:
    


    dims=["longitude","latitude","basin"]
    coords={"longitude":dsera5.longitude,"latitude":dsera5.latitude,"basin":basinpolys.name}


    dtmp=xr.DataArray(np.zeros([dsera5.sizes['longitude'],dsera5.sizes['latitude'],len(basinpolys.geometry)]),coords=coords,dims=dims).stack(lonlat=("longitude","latitude"))


    #create a geoDataframe of points from the grid
    ggrd=gpd.GeoDataFrame(geometry=[Point(lon,lat) for lon,lat in dtmp.lonlat.values],crs=4326)
    
    if basinpolys.geometry.crs != ggrd.crs:
        #possibly convert the lon/lat grid in the desired projection before doing the polygon test
        ggrd=ggrd.to_crs(basinpolys.geometry.crs)
    

    #query using a spatial index and set values to 1
    for i,poly in enumerate(basinpolys.geometry): 
        idx=ggrd.sindex.query(poly,predicate="contains")
        dtmp[i,idx]=1.0
    
    
    dtmp=dtmp.unstack("lonlat")

    return dtmp

# %%
dsmasks=era5_polygonmask(gdfbasins,ds_flux)

# %%
dsmasks.sel(basin="SHEBELLE").plot()

# %%
from shxarray.earth.constants import a_earth
dis=np.deg2rad(np.median(np.diff(ds_flux.longitude)))*a_earth
area=dis**2
pxl_wght=np.cos(np.deg2rad(ds_flux.latitude))*area
pxl_wght=xr.DataArray(pxl_wght,dims=["latitude"],coords=dict(latitude=ds_flux.latitude))

# %%
ds_flux_wghtd=pxl_wght*ds_flux

# %%
import dask.array as da
dsmasks=dsmasks.chunk(chunks={"latitude":180,"longitude":360})
ds_flux_wghtd=ds_flux_wghtd.chunk(chunks={"latitude":180,"longitude":360})

# %%
masked_flux=dsmasks*ds_flux_wghtd

# %%
basin_flux=masked_flux.sum(dim=("latitude","longitude"))

# %%
from shxarray.earth.constants import rho_water
basin_flux=basin_flux/rho_water

# %%
basin_flux['avg_ie'] = basin_flux['avg_ie'].compute()

# %%
basin_flux['avg_tprate'] = basin_flux['avg_tprate'].compute()

# %%
display(basin_flux)
# Out:
# <xarray.Dataset> Size: 555kB
# Dimensions:     (valid_time: 276, basin: 124)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB dask.array<chunksize=(276,), meta=np.ndarray>
#   * basin       (basin) object 992B 'SETIT' ... 'TIBETAN PLATEAU'
# Data variables:
#     avg_ie      (basin, valid_time) float64 274kB -1.593e+03 ... -2.746e+03
#     avg_tprate  (basin, valid_time) float64 274kB 315.8 158.0 ... 2.051e+03

# %%
basareas=pd.Series(data=gdfbasins.SUB_AREA.values,index=gdfbasins.name)
basinareas=(np.array([basareas[name] for name in basin_flux.basin.values])) *10**6

# %%
basin_flux=basin_flux.assign_coords(basin_area=("basin",basinareas))
basin_flux
# Out:
# <xarray.Dataset> Size: 556kB
# Dimensions:     (valid_time: 276, basin: 124)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB dask.array<chunksize=(276,), meta=np.ndarray>
#   * basin       (basin) object 992B 'SETIT' ... 'TIBETAN PLATEAU'
#     basin_area  (basin) float64 992B 2.363e+11 5.19e+11 ... 1.426e+12 5.908e+11
# Data variables:
#     avg_ie      (basin, valid_time) float64 274kB -1.593e+03 ... -2.746e+03
#     avg_tprate  (basin, valid_time) float64 274kB 315.8 158.0 ... 2.051e+03

# %%
basin_flux["basin_area"]=basin_flux["basin_area"].assign_attrs(long_name="Surface area of each hydrological basin",units="m**2")

# %%
basin_flux["avg_ie"]=basin_flux.avg_ie.assign_attrs(long_name="Time-mean moisture flux",units="m**3 s**-1",
comment="To convert to m s**-1, divide avg_ie by the area of the basin")
basin_flux["avg_tprate"]=basin_flux.avg_tprate.assign_attrs(long_name="Time-mean total precipitation rate",units="m**3 s**-1",
comment="To convert to m s**-1, divide avg_tprate by the area of the basin")

# %%
basin_flux
# Out:
# <xarray.Dataset> Size: 556kB
# Dimensions:     (valid_time: 276, basin: 124)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB dask.array<chunksize=(276,), meta=np.ndarray>
#   * basin       (basin) object 992B 'SETIT' ... 'TIBETAN PLATEAU'
#     basin_area  (basin) float64 992B 2.363e+11 5.19e+11 ... 1.426e+12 5.908e+11
# Data variables:
#     avg_ie      (basin, valid_time) float64 274kB -1.593e+03 ... -2.746e+03
#     avg_tprate  (basin, valid_time) float64 274kB 315.8 158.0 ... 2.051e+03

# %%
#save to netcdf for re-use
tp_et_rateout=os.path.join(datadir,conf['ncp-et'])
basin_flux.to_netcdf(tp_et_rateout)

# %% [markdown]
# ## Compute cumulative monthly precipitation and evapotranspiration (in meters) over a selected basin

# %%
N=ds_flux.valid_time.dt.days_in_month #Number of days in month
bas_total_mass=basin_flux*(N*24*3600)

# %%
display(bas_total_mass)  # in m3
# Out:
# <xarray.Dataset> Size: 556kB
# Dimensions:     (valid_time: 276, basin: 124)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB '0001' '0001' '0001' ... '0005' '0005'
#   * basin       (basin) object 992B 'SETIT' ... 'TIBETAN PLATEAU'
#     basin_area  (basin) float64 992B 2.363e+11 5.19e+11 ... 1.426e+12 5.908e+11
# Data variables:
#     avg_ie      (basin, valid_time) float64 274kB -4.13e+09 ... -7.355e+09
#     avg_tprate  (basin, valid_time) float64 274kB 8.185e+08 ... 5.493e+09

# %%
total_mass=bas_total_mass.sel(basin="SHEBELLE")
total_mass
# Out:
# <xarray.Dataset> Size: 11kB
# Dimensions:     (valid_time: 276)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB '0001' '0001' '0001' ... '0005' '0005'
#     basin       <U8 32B 'SHEBELLE'
#     basin_area  float64 8B 7.979e+11
# Data variables:
#     avg_ie      (valid_time) float64 2kB -5.207e+10 -5.397e+10 ... -3.401e+10
#     avg_tprate  (valid_time) float64 2kB 1.072e+11 3.779e+10 ... 3.8e+10

# %%
basin_area=gdfbasins.SUB_AREA.loc[gdfbasins.name=="SHEBELLE"].values
basin_area
# Out:
# array([797881.4])

# %%
water_height=total_mass/total_mass.basin_area
display(water_height) # in meters
# Out:
# <xarray.Dataset> Size: 11kB
# Dimensions:     (valid_time: 276)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 ... 2025-...
#     expver      (valid_time) <U4 4kB '0001' '0001' '0001' ... '0005' '0005'
#     basin       <U8 32B 'SHEBELLE'
#     basin_area  float64 8B 7.979e+11
# Data variables:
#     avg_ie      (valid_time) float64 2kB -0.06526 -0.06765 ... -0.01978 -0.04263
#     avg_tprate  (valid_time) float64 2kB 0.1344 0.04736 ... 0.0005085 0.04763

# %%
water_height.avg_tprate.plot()

# %%
from scipy import integrate

months=((bas_total_mass.valid_time-bas_total_mass.valid_time[0]).dt.days)/bas_total_mass.valid_time.dt.days_in_month
cumulative_precip=integrate.cumulative_trapezoid(water_height.avg_tprate,months,dx=1.0,axis=0,initial=None)
cumulative_et=integrate.cumulative_trapezoid(water_height.avg_ie,months,dx=1.0,axis=0,initial=None)

# %%
init_pnt=np.zeros(1)
cumulative_precip=np.concatenate([init_pnt,cumulative_precip],axis=0) 
cumulative_et=np.concatenate([init_pnt,cumulative_et],axis=0)

# %%
water_height["cumulative_precip"]=("valid_time",cumulative_precip)
water_height["cumulative_et"]=("valid_time",cumulative_et)

# %%
water_height
# Out:
# <xarray.Dataset> Size: 16kB
# Dimensions:            (valid_time: 276)
# Coordinates:
#     number             int64 8B 0
#   * valid_time         (valid_time) datetime64[ns] 2kB 2002-04-01T06:00:00 .....
#     expver             (valid_time) <U4 4kB '0001' '0001' ... '0005' '0005'
#     basin              <U8 32B 'SHEBELLE'
#     basin_area         float64 8B 7.979e+11
# Data variables:
#     avg_ie             (valid_time) float64 2kB -0.06526 -0.06765 ... -0.04263
#     avg_tprate         (valid_time) float64 2kB 0.1344 0.04736 ... 0.04763
#     cumulative_precip  (valid_time) float64 2kB 0.0 0.08794 ... 7.624 6.952
#     cumulative_et      (valid_time) float64 2kB 0.0 -0.06431 ... -9.821 -8.95

# %%
water_height.cumulative_et.plot()

# %%
water_height.cumulative_precip.plot()
